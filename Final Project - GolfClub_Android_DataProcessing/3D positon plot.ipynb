# %%
import pandas as pd

data = pd.read_csv("Golf_0.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 10 columns):
# Time          152 non-null object
# GyroX         151 non-null float64
# GyroY         151 non-null float64
# GyroZ         151 non-null float64
# PosX          151 non-null float64
# PosY          151 non-null float64
# PosZ          151 non-null float64
# ForPie        140 non-null object
# ForThe        140 non-null object
# Unnamed: 9    0 non-null float64
# dtypes: float64(7), object(3)
# memory usage: 10.2+ KB

# %%
data = pd.DataFrame(data=data)
data = data.drop(0,0)
data = data.drop(["Time", "GyroX", "GyroY","GyroZ", "Unnamed: 9", "ForPie", "ForThe"], 1)
print(data)
# Out:
#              PosX      PosY      PosZ
# 1   -2.789032e-07  0.000285  0.600000
# 2   -1.203325e-05  0.001728  0.599998
# 3   -5.060730e-05  0.003177  0.599992
# 4   -7.100872e-05  0.003342  0.599991
# 5   -1.006481e-04  0.004039  0.599986
# ..            ...       ...       ...
# 147 -6.530492e-02  0.198552  0.562417
# 148 -6.591453e-02  0.199681  0.561946
# 149 -6.633450e-02  0.200402  0.561640
# 150 -6.650038e-02  0.201008  0.561403
# 151 -6.625910e-02  0.200768  0.561518
#
# [151 rows x 3 columns]

# %%
import numpy as np
data.applymap(np.isreal)
# Out:
#      PosX  PosY  PosZ
# 1    True  True  True
# 2    True  True  True
# 3    True  True  True
# 4    True  True  True
# 5    True  True  True
# ..    ...   ...   ...
# 850  True  True  True
# 851  True  True  True
# 852  True  True  True
# 853  True  True  True
# 854  True  True  True
#
# [854 rows x 3 columns]

# %%
data.plot()

# %%
data.plot()

# %%
x = data['PosX']

# %%
y = data['PosY']

# %%
z = data['PosZ']

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(x, y, -z, 'green');
ax.scatter3D(x, y, -z, 'Greens')

# %%
ay = plt.axes()
ay.plot(y, -z,'red');
