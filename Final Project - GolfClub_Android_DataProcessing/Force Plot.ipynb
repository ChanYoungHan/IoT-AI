# %%
import pandas as pd

data = pd.read_csv("test-20.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 11 columns):
# Time           212 non-null object
# GyroX          211 non-null float64
# GyroY          211 non-null float64
# GyroZ          211 non-null float64
# PosX           211 non-null float64
# PosY           211 non-null float64
# PosZ           211 non-null float64
# ForPie         209 non-null float64
# ForThe         209 non-null float64
# Unnamed: 9     0 non-null float64
# Unnamed: 10    0 non-null float64
# dtypes: float64(10), object(1)
# memory usage: 17.5+ KB

# %%
data = pd.DataFrame(data=data)
data = data.drop(0,0)
data = data.drop(["Time", "GyroX", "GyroY","GyroZ", "Unnamed: 9","Unnamed: 10"], 1)
dataTor = data.drop(["PosX", "PosY","PosZ"], 1)
dataPos = data.drop(["ForPie", "ForThe"], 1)
print(dataTor)
print(dataPos)
# Out:
#        ForPie    ForThe
# 1    0.000000  0.000000
# 2         NaN       NaN
# 3         NaN       NaN
# 4   -0.029764 -7.801945
# 5    1.818895 -2.942321
# ..        ...       ...
# 207 -0.098406  0.051921
# 208 -0.698519  1.336012
# 209  1.213953 -1.975149
# 210  0.623315 -0.878840
# 211  0.162829 -0.084657
#
# [211 rows x 2 columns]
#          PosX      PosY      PosZ
# 1    0.000000  0.000000  0.600000
# 2    0.000000  0.000000  0.600000
# 3    0.000000  0.000000  0.600000
# 4   -0.000123 -0.010537  0.599907
# 5   -0.001074 -0.031324  0.599181
# ..        ...       ...       ...
# 207 -0.021256  0.012194  0.599499
# 208 -0.018183  0.010345  0.599635
# 209 -0.016284  0.009261  0.599708
# 210 -0.013699  0.007846  0.599792
# 211 -0.011860  0.006868  0.599843
#
# [211 rows x 3 columns]

# %%
import numpy as np
dataTor.applymap(np.isreal)
# Out:
#      ForPie  ForThe
# 1      True    True
# 2      True    True
# 3      True    True
# 4      True    True
# 5      True    True
# ..      ...     ...
# 207    True    True
# 208    True    True
# 209    True    True
# 210    True    True
# 211    True    True
#
# [211 rows x 2 columns]

# %%
dataPos.plot()
dataTor.plot()

# %%
x = data['PosX']

# %%
y = data['PosY']

# %%
z = data['PosZ']

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(z, x, y, 'green');
ax.scatter3D(z, x, y, 'Greens')

# %%
ay = plt.axes()
ay.plot(y, -z,'red');
